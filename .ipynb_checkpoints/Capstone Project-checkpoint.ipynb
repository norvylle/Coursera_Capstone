# %% [markdown]
# ## This Notebook will be used for the Capstone Project

# %% [markdown]
# ### Import required packages

# %%
import pandas as pd
import numpy as np

#! pip install sklearn
from sklearn.cluster import KMeans

# ! pip install requests geopy
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests
import matplotlib.cm as cm
import matplotlib.colors as colors

#! pip install folium
import folium # map rendering library

# %% [markdown]
# ### Scraping of table on the webpage

# %%
df = pd.read_html("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")
df = df[0]
df
# Out:
#     Postal Code           Borough  \
# 0           M1A      Not assigned
# 1           M2A      Not assigned
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# ..          ...               ...
# 175         M5Z      Not assigned
# 176         M6Z      Not assigned
# 177         M7Z      Not assigned
# 178         M8Z         Etobicoke
# 179         M9Z      Not assigned
#
#                                           Neighborhood
# 0                                         Not assigned
# 1                                         Not assigned
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# ..                                                 ...
# 175                                       Not assigned
# 176                                       Not assigned
# 177                                       Not assigned
# 178  Mimico NW, The Queensway West, South of Bloor,...
# 179                                       Not assigned
#
# [180 rows x 3 columns]

# %%
df = df[df["Borough"].str.contains("Not assigned") == False]
df = df.reset_index(drop=True)
df.head(10)
# Out:
#   Postal Code           Borough                                 Neighborhood
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 5         M9A         Etobicoke      Islington Avenue, Humber Valley Village
# 6         M1B       Scarborough                               Malvern, Rouge
# 7         M3B        North York                                    Don Mills
# 8         M4B         East York              Parkview Hill, Woodbine Gardens
# 9         M5B  Downtown Toronto                     Garden District, Ryerson

# %% [markdown]
# ### Dataframe shape

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# ### Adding Coordinates for each  Postal Code
#
# We merge the coordinates according to each Borough's Postal Code

# %%
geo = pd.read_csv("Geospatial_Coordinates.csv")
new_df = pd.merge(df, geo, on=['Postal Code'])
new_df.head()
# Out:
#   Postal Code           Borough                                 Neighborhood  \
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494

# %% [markdown]
# ### Preprocessing of Data
# We do one-hot enconding on the DataFrame based on Boroughs that contain the word Toronto

# %%
# one hot encoding
a = new_df[new_df['Borough'].str.contains("Toronto")]

df_onehot = pd.get_dummies(a[['Borough']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
df_onehot['Neighborhood'] = new_df['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [df_onehot.columns[-1]] + list(df_onehot.columns[:-1])
df_onehot = df_onehot[fixed_columns]

#Group according to Neighborhood
df_grouped = df_onehot.groupby('Neighborhood').mean().reset_index()
df_grouped
# Out:
#                                          Neighborhood  Central Toronto  \
# 0                                         Berczy Park                0
# 1        Brockton, Parkdale Village, Exhibition Place                0
# 2   Business reply mail Processing Centre, South C...                0
# 3   CN Tower, King and Spadina, Railway Lands, Har...                0
# 4                                  Central Bay Street                0
# 5                                            Christie                0
# 6                                Church and Wellesley                0
# 7                      Commerce Court, Victoria Hotel                0
# 8                                          Davisville                1
# 9                                    Davisville North                1
# 10                       Dufferin, Dovercourt Village                0
# 11             First Canadian Place, Underground city                0
# 12    Forest Hill North & West, Forest Hill Road Park                1
# 13                           Garden District, Ryerson                0
# 14  Harbourfront East, Union Station, Toronto Islands                0
# 15                      High Park, The Junction South                0
# 16                     India Bazaar, The Beaches West                0
# 17          Kensington Market, Chinatown, Grange Park                0
# 18                                      Lawrence Park                1
# 19                           Little Portugal, Trinity                0
# 20                        Moore Park, Summerhill East                1
# 21                  North Toronto West, Lawrence Park                1
# 22                             Parkdale, Roncesvalles                0
# 23        Queen's Park, Ontario Provincial Government                0
# 24                          Regent Park, Harbourfront                0
# 25                           Richmond, Adelaide, King                0
# 26                                           Rosedale                0
# 27                                           Roselawn                1
# 28                                 Runnymede, Swansea                0
# 29                                     St. James Town                0
# 30                        St. James Town, Cabbagetown                0
# 31                                     Stn A PO Boxes                0
# 32                                    Studio District                0
# 33  Summerhill West, Rathnelly, South Hill, Forest...                1
# 34                The Annex, North Midtown, Yorkville                1
# 35                                        The Beaches                0
# 36                       The Danforth West, Riverdale                0
# 37           Toronto Dominion Centre, Design Exchange                0
# 38                     University of Toronto, Harbord                0
#
#     Downtown Toronto  East Toronto  West Toronto
# 0                  1             0             0
# 1                  0             0             1
# 2                  0             1             0
# 3                  1             0             0
# 4                  1             0             0
# 5                  1             0             0
# 6                  1             0             0
# 7                  1             0             0
# 8                  0             0             0
# 9                  0             0             0
# 10                 0             0             1
# 11                 1             0             0
# 12                 0             0             0
# 13                 1             0             0
# 14                 1             0             0
# 15                 0             0             1
# 16                 0             1             0
# 17                 1             0             0
# 18                 0             0             0
# 19                 0             0             1
# 20                 0             0             0
# 21                 0             0             0
# 22                 0             0             1
# 23                 1             0             0
# 24                 1             0             0
# 25                 1             0             0
# 26                 1             0             0
# 27                 0             0             0
# 28                 0             0             1
# 29                 1             0             0
# 30                 1             0             0
# 31                 1             0             0
# 32                 0             1             0
# 33                 0             0             0
# 34                 0             0             0
# 35                 0             1             0
# 36                 0             1             0
# 37                 1             0             0
# 38                 1             0             0

# %% [markdown]
# We also obtain the coordinates for Toronto.

# %%
address = 'Toronto, Ontario'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude,",",longitude)
# Out:
# 43.6534817 , -79.3839347

# %% [markdown]
# ### Clustering
#
# We run K-means clustering on K=4

# %%
# set number of clusters
kclusters = 4

df_grouped_clustering = df_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(df_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 2, 3, 0, 0, 0, 0, 0, 1, 1], dtype=int32)

# %%
df_grouped.insert(0, 'Cluster Labels', kmeans.labels_)

df_merged = a.join(df_grouped.set_index('Neighborhood'), on='Neighborhood').reset_index()

df_merged.head()
# Out:
#    index Postal Code           Borough  \
# 0      2         M5A  Downtown Toronto
# 1      4         M7A  Downtown Toronto
# 2      9         M5B  Downtown Toronto
# 3     15         M5C  Downtown Toronto
# 4     19         M4E      East Toronto
#
#                                   Neighborhood   Latitude  Longitude  \
# 0                    Regent Park, Harbourfront  43.654260 -79.360636
# 1  Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# 2                     Garden District, Ryerson  43.657162 -79.378937
# 3                               St. James Town  43.651494 -79.375418
# 4                                  The Beaches  43.676357 -79.293031
#
#    Cluster Labels  Central Toronto  Downtown Toronto  East Toronto  \
# 0               0                0                 1             0
# 1               0                0                 1             0
# 2               0                0                 1             0
# 3               0                0                 1             0
# 4               3                0                 0             1
#
#    West Toronto
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %% [markdown]
# We then create the map with clusters.

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

markers_colors = []
for lat, lon, poi, cluster in zip(df_merged['Latitude'], df_merged['Longitude'], df_merged['Neighborhood'], df_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# We can see above the four clusters created.
#
# Below we can see which Postal Code are group into clusters
#
# ### Cluster 1

# %%
df_merged.loc[df_merged['Cluster Labels'] == 0, df_merged.columns[[1] + list(range(4, df_merged.shape[1]))]]
# Out:
#    Postal Code   Latitude  Longitude  Cluster Labels  Central Toronto  \
# 0          M5A  43.654260 -79.360636               0                0
# 1          M7A  43.662301 -79.389494               0                0
# 2          M5B  43.657162 -79.378937               0                0
# 3          M5C  43.651494 -79.375418               0                0
# 5          M5E  43.644771 -79.373306               0                0
# 6          M5G  43.657952 -79.387383               0                0
# 7          M6G  43.669542 -79.422564               0                0
# 8          M5H  43.650571 -79.384568               0                0
# 10         M5J  43.640816 -79.381752               0                0
# 13         M5K  43.647177 -79.381576               0                0
# 16         M5L  43.648198 -79.379817               0                0
# 27         M5S  43.662696 -79.400049               0                0
# 30         M5T  43.653206 -79.400049               0                0
# 32         M5V  43.628947 -79.394420               0                0
# 33         M4W  43.679563 -79.377529               0                0
# 34         M5W  43.646435 -79.374846               0                0
# 35         M4X  43.667967 -79.367675               0                0
# 36         M5X  43.648429 -79.382280               0                0
# 37         M4Y  43.665860 -79.383160               0                0
#
#     Downtown Toronto  East Toronto  West Toronto
# 0                  1             0             0
# 1                  1             0             0
# 2                  1             0             0
# 3                  1             0             0
# 5                  1             0             0
# 6                  1             0             0
# 7                  1             0             0
# 8                  1             0             0
# 10                 1             0             0
# 13                 1             0             0
# 16                 1             0             0
# 27                 1             0             0
# 30                 1             0             0
# 32                 1             0             0
# 33                 1             0             0
# 34                 1             0             0
# 35                 1             0             0
# 36                 1             0             0
# 37                 1             0             0

# %% [markdown]
# ### Cluster 2

# %%
df_merged.loc[df_merged['Cluster Labels'] == 1, df_merged.columns[[1] + list(range(4, df_merged.shape[1]))]]
# Out:
#    Postal Code   Latitude  Longitude  Cluster Labels  Central Toronto  \
# 18         M4N  43.728020 -79.388790               1                1
# 19         M5N  43.711695 -79.416936               1                1
# 20         M4P  43.712751 -79.390197               1                1
# 21         M5P  43.696948 -79.411307               1                1
# 23         M4R  43.715383 -79.405678               1                1
# 24         M5R  43.672710 -79.405678               1                1
# 26         M4S  43.704324 -79.388790               1                1
# 29         M4T  43.689574 -79.383160               1                1
# 31         M4V  43.686412 -79.400049               1                1
#
#     Downtown Toronto  East Toronto  West Toronto
# 18                 0             0             0
# 19                 0             0             0
# 20                 0             0             0
# 21                 0             0             0
# 23                 0             0             0
# 24                 0             0             0
# 26                 0             0             0
# 29                 0             0             0
# 31                 0             0             0

# %% [markdown]
# ### Cluster 3

# %%
df_merged.loc[df_merged['Cluster Labels'] == 2, df_merged.columns[[1] + list(range(4, df_merged.shape[1]))]]
# Out:
#    Postal Code   Latitude  Longitude  Cluster Labels  Central Toronto  \
# 9          M6H  43.669005 -79.442259               2                0
# 11         M6J  43.647927 -79.419750               2                0
# 14         M6K  43.636847 -79.428191               2                0
# 22         M6P  43.661608 -79.464763               2                0
# 25         M6R  43.648960 -79.456325               2                0
# 28         M6S  43.651571 -79.484450               2                0
#
#     Downtown Toronto  East Toronto  West Toronto
# 9                  0             0             1
# 11                 0             0             1
# 14                 0             0             1
# 22                 0             0             1
# 25                 0             0             1
# 28                 0             0             1

# %% [markdown]
# ### Cluster 4

# %%
df_merged.loc[df_merged['Cluster Labels'] == 3, df_merged.columns[[1] + list(range(4, df_merged.shape[1]))]]
# Out:
#    Postal Code   Latitude  Longitude  Cluster Labels  Central Toronto  \
# 4          M4E  43.676357 -79.293031               3                0
# 12         M4K  43.679557 -79.352188               3                0
# 15         M4L  43.668999 -79.315572               3                0
# 17         M4M  43.659526 -79.340923               3                0
# 38         M7Y  43.662744 -79.321558               3                0
#
#     Downtown Toronto  East Toronto  West Toronto
# 4                  0             1             0
# 12                 0             1             0
# 15                 0             1             0
# 17                 0             1             0
# 38                 0             1             0
